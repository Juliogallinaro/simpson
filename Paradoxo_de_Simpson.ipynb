# %% [markdown]
# <a href="https://colab.research.google.com/github/Juliogallinaro/simpson/blob/main/Paradoxo_de_Simpson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Paradoxo de Simpson

# %%
# importa o pandas
import pandas as pd

# gráficos
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Simpson = pd.read_csv('https://raw.githubusercontent.com/Juliogallinaro/simpson/main/simpson.csv')

# %%
Simpson.head()
# Out:
#            x         y  a1  a2  a3  a4
# 0  13.944627  8.130532  v2  v1  v3  v3
# 1   2.781110 -1.199000  v2  v3  v1  v4
# 2  11.558056  8.062959  v2  v2  v3  v4
# 3   1.452319 -3.691675  v2  v1  v1  v4
# 4  10.862521  5.505988  v3  v1  v3  v3

# %%
sns.lmplot(data=Simpson,x='x',y='y')

# %%
sns.lmplot(data=Simpson,x='x',y='y',hue='a1')

# %%
sns.lmplot(data=Simpson,x='x',y='y',hue='a2')

# %%
sns.lmplot(data=Simpson,x='x',y='y',hue='a3')
